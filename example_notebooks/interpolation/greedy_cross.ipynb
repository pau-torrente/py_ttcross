# %%
import numpy as np
import numba as nb
import matplotlib.pyplot as plt
from py_ttcross.regular_tt_cross.dmrg_cross import *
from py_ttcross.quantic_tt_cross.interpolators_1D import *

# %% [markdown]
# # N-Dimensional interpolator

# %%
# grid_creation
num_var = 40
subdivision = 25
temp = [np.linspace(1, 2, subdivision) for _ in range(num_var)]
grid = np.array(temp)


def test_function(x: np.ndarray) -> np.float64:
    return np.sinc(np.sum(x))


# Check that the function can be compiled:

try:
    nb.njit()(test_function)
    print("Function can be compiled!")
except:
    print("Function cannot be compiled!")
# Out:
# Function can be compiled!

# %%
# interpolator initialization

example_interpolator = greedy_cross(
    func=test_function,
    num_variables=num_var,
    grid=grid,
    tol=1e-8,
    max_bond=5,
    sweeps=10,
    is_f_complex=False,
    pivot_initialization="first_n",
)
# Out:
# Function successfully compiled with numba.
# Initialization succesfully done after time: 0.001875162124633789 seconds and 1 tries.

# %%
tensors = example_interpolator.run()
# Out:
# Sweep 1
# Sweep 2
# Sweep 3

# %%
print("Time spent to do the whole computation =", example_interpolator.total_time, "s")
print("Time spent building superblock tensors =", example_interpolator.super_block_time, "s")
# Out:
# Time spent to do the whole computation = 2.193875789642334 s
# Time spent building superblock tensors = 1.5615730285644531 s

# %%
for t in tensors:
    print(t.shape)
# Out:
# (1, 25, 4)
# (4, 4)
# (4, 25, 4)
# (4, 4)
# (4, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 5)
# (5, 5)
# (5, 25, 4)
# (4, 4)
# (4, 25, 1)

# %%
# This error corresponds to np.sum(np.abs(superblock-superblock_approx)) at each pivot finding step

plt.plot(example_interpolator.error[100:])

# %%
# We can also evaluate from the ttcross interpolation directly

for _ in range(5):
    sample = np.random.rand(num_var) + 1
    print("real value =", test_function(sample))
    print("interpolated value =", example_interpolator.eval(sample))
# Out:
# real value = 0.0051517083710860565
# interpolated value = 0.005090609259021613
# real value = -0.005253345486135951
# interpolated value = -0.005347771695088552
# real value = 0.0044702161990025895
# interpolated value = 0.004420189347306308
# real value = -0.003483172190418806
# interpolated value = -0.003769851431965586
# real value = 0.00229502707060243
# interpolated value = 0.0030765911340137828

# %% [markdown]
# ## 1D Interpolator

# %%
def test_func(x):
    B = 2 ** (-30)
    return np.cos(x / B) * np.cos(x / (4 * np.sqrt(5) * B)) * np.exp(-(x**2)) + 2 * np.exp(-x)

# %%
interval = [0, 2 ** (-23)]
d = 15

test_interpolator = greedy_one_dim_func_interpolator(
    func=test_func,
    interval=interval,
    d=d,
    complex_function=False,
    max_bond=5,
    pivot_finder_tol=1e-8,
    sweeps=5,
)

# %%
test_interpolator.interpolate()
# Out:
# Function not compiled with numba. Using non-compiled version.
# Initialization succesfully done after time: 0.0050885677337646484 seconds and 1 tries.
# Sweep 1
# Sweep 2
# Sweep 3
# Sweep 4

# %%
import matplotlib.pyplot as plt

x = np.linspace(0, 2 ** (-23), 1000)

y = [test_func(x_i) for x_i in x]

interpolation = np.array([test_interpolator.eval(x_i) for x_i in x])

plt.plot(x, y, label="exact value")
plt.plot(x, interpolation, label="Interpolation")

plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Interpolation of $f(x) = \cos(x / 2^{-30})\cos(x / (4\sqrt{5}2^{-30}))e^{-x^2} + 2e^{-x}$")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\c'
# <>:14: SyntaxWarning: invalid escape sequence '\c'
# /tmp/ipykernel_2985/1220165210.py:14: SyntaxWarning: invalid escape sequence '\c'
#   plt.title("Interpolation of $f(x) = \cos(x / 2^{-30})\cos(x / (4\sqrt{5}2^{-30}))e^{-x^2} + 2e^{-x}$")
